# %% [markdown]
# <a href="https://colab.research.google.com/github/solomontessema/learn/blob/master/Assignment_1_Retreive_data_from_a_table.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name:** Your Name Here
#
# **Date:** Month/day 2025

# %% [markdown]
# **The following code installs and loads sqlite, you do not need to know this code at this time. Just Run to install and load the programs you need to do your homework.**

# %%
# Install SQL magic (if needed)
# !pip install ipython-sql

import pandas as pd
import sqlite3
import prettytable as pt
pt.prettytable.DEFAULT = pt.PLAIN_COLUMNS

# Load SQL magic extension
# %load_ext sql

# Load dataset
url = "https://ionnova.com/superstore.csv"
df = pd.read_csv(url, encoding="latin1")

# Save database as a file (instead of in-memory)
conn = sqlite3.connect("superstore.db")  # Ensures persistence
df.to_sql("superstore", conn, index=False, if_exists="replace")

# Use persistent SQLite file for SQL magic
# %sql sqlite:///superstore.db

import sql
sql.run.prettytable.__dict__["DEFAULT"] = sql.run.prettytable.PLAIN_COLUMNS
# Out:
# ...
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# **First Let's see what the data looks like, lets limit the rows to 5 rows. I did this for you. Just run the cell below.**

# %%
# %%sql
# SELECT *
# FROM superstore
# LIMIT 5;
# Out:
#    sqlite:///:memory:
#  * sqlite:///superstore.db
# Done.
# [(32298, 'CA-2012-124891', '31-07-2012', '31-07-2012', 'Same Day', 'RH-19495', 'Rick Hansen', 'Consumer', 'New York City', 'New York', 'United States', 10024.0, 'US', 'East', 'TEC-AC-10003033', 'Technology', 'Accessories', 'Plantronics CS510 - Over-the-Head monaural Wireless Headset System', 2309.65, 7, 0.0, 762.1845, 933.57, 'Critical'),
#  (26341, 'IN-2013-77878', '05-02-2013', '07-02-2013', 'Second Class', 'JR-16210', 'Justin Ritter', 'Corporate', 'Wollongong', 'New South Wales', 'Australia', None, 'APAC', 'Oceania', 'FUR-CH-10003950', 'Furniture', 'Chairs', 'Novimex Executive Leather Armchair, Black', 3709.395, 9, 0.1, -288.765, 923.63, 'Critical'),
# ...

# %% [markdown]
# **Now is your turn. Do the same thing as I did above, select all columns from superstore table, but limit the rows to 10 rows.:**

# %%
# %%sql
# 'Replace this with your code'
# Out:
#    sqlite:///:memory:
#  * sqlite:///superstore.db
# (sqlite3.OperationalError) near "'Replace this with your code'": syntax error
# [SQL: 'Replace this with your code']
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# **Now query only for 3 columns, City, State, and Country. Limit the Rows to 15. I have started the code for you. Complete the missing part.**

# %%
# %%sql
# SELECT City, State, Country
# FROM superstore
# Limit 15
# Out:
#    sqlite:///:memory:
#  * sqlite:///superstore.db
# Done.
# [('New York City', 'New York', 'United States'),
#  ('Wollongong', 'New South Wales', 'Australia'),
#  ('Brisbane', 'Queensland', 'Australia'),
#  ('Berlin', 'Berlin', 'Germany'),
#  ('Dakar', 'Dakar', 'Senegal'),
#  ('Sydney', 'New South Wales', 'Australia'),
#  ('Porirua', 'Wellington', 'New Zealand'),
#  ('Hamilton', 'Waikato', 'New Zealand'),
#  ('Sacramento', 'California', 'United States'),
#  ('Concord', 'North Carolina', 'United States'),
#  ('Alexandria', 'Virginia', 'United States'),
#  ('Kabul', 'Kabul', 'Afghanistan'),
#  ('Jizan', 'Jizan', 'Saudi Arabia'),
#  ('Toledo', 'Parana', 'Brazil'),
#  ('Mudanjiang', 'Heilongjiang', 'China')]

# %% [markdown]
# **Now query only for 3 columns, City, State, and Country. Limit the Rows to 15. I have started the code for you. Complete the missing part.**

# %%
# %%sql
# SELECT *
# FROM superstore
# WHERE Country = 'United States'
# LIMIT 20
# Out:
#    sqlite:///:memory:
#  * sqlite:///superstore.db
# Done.
# [(32298, 'CA-2012-124891', '31-07-2012', '31-07-2012', 'Same Day', 'RH-19495', 'Rick Hansen', 'Consumer', 'New York City', 'New York', 'United States', 10024.0, 'US', 'East', 'TEC-AC-10003033', 'Technology', 'Accessories', 'Plantronics CS510 - Over-the-Head monaural Wireless Headset System', 2309.65, 7, 0.0, 762.1845, 933.57, 'Critical'),
#  (40155, 'CA-2014-135909', '14-10-2014', '21-10-2014', 'Standard Class', 'JW-15220', 'Jane Waco', 'Corporate', 'Sacramento', 'California', 'United States', 95823.0, 'US', 'West', 'OFF-BI-10003527', 'Office Supplies', 'Binders', 'Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind', 5083.96, 5, 0.2, 1906.485, 867.69, 'Low'),
# ...
